# %% [markdown]
# # **PROBABILIDAD Y SOULBOUND
#
#
# **PRIMER TIRADA**
# ---
# Ataque normal (requiere 4 o mas)
#
# Se tiran 2 dados para saber si es exitoso:
# Resultado dado 1: **1** (fallido).  Resultado dado 2: **3** (fallido).
#
# FALLIDO
#
# ---
#
# c
#
# Para que R sea exitoso almenos debe tener uno de los valores de S por lo que necesitamos una interseccion
#
# R∩S={1,3}∩{4,5,6}=∅
#
#
# EL RESULTADO FUE FALLIDO
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SEGUNDA TIRADA**
# ---
#
# Ataque rapido (requiere 5 o mas)
#
# Se tiran 2 dados: Resultado dado 1: **4** (fallido). Resultado dado 2: 6 (exitoso y critico)
#
# Se tiran 3 dados para determinar el daños: Resultados: 4, 4, 4 = 12
#
# 12 X 2 = 24 (bonus critico) DAñO TOTAL 24
#
# ---
#
# U={1,2,3,4,5,6} universo
#
# S={5,6} opciones exitosas
#
# R={4,6} respuestas optenidas
#
# interseccion entre R y S
#
# R∩S={4,6}∩{5,6}={6}
#
# **DETERMINAR DAÑO** D={4,4,4} 4+4+4=12
#
# Como el ataque fue crítico, el daño se multiplica por 2:
# 12×2=24
#
# El ataque es exitoso porque
# 𝑅∩𝑆≠∅R∩S=∅
#
# Es crítico porque 6∈𝑅6∈R.
#
# El daño se calcula con los valores en 𝐷 D y se duplica por el crítico.

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# Definir los conjuntos
S = {5, 6}
R = {4, 6}

# Crear el diagrama de Venn
venn = venn2([R, S], ('R', 'S'))

# Resaltar la intersección
venn.get_label_by_id('11').set_text('6')
venn.get_label_by_id('10').set_text('4')
venn.get_label_by_id('01').set_text('5')

# Mostrar el gráfico
plt.title("Diagrama de Venn de R y S")
plt.show()

# %% [markdown]
# **TERCER TIRADA**
# ---
# Ataque especial (no me acuerdo cual) bonus de doble tiro (requiere 5 o mas)
#
# Se tiran 3 dados 2 veces:
#
# * Resultado tiro 1: Dado 1: **5** (exitoso). Dado 2: **5** (exitoso). Dado 3: **4** (fallido).
# * Resultado tiro 2: Dado 2: **4** (fallido). Dado 2: **3** (fallido). Dado 3: **1** (fallido).
#
# Se tiran 2 dados para  para determinar el daño: Resultados:

# %% [markdown]
# **CUARTA TIRADA**
# ---
# Ataque normal (requiere 4 o mas)
#
# Se tiran 3 dados: Dado 1: **5** (exitoso). Dado 2: **2** (fallido). Dado 3: **2** (fallido).
#
# Se tira 1 dado para determinar el daño: Resultados: 6.
#
# 6 x 2 = 12 (bonus critico) DAñO TOTAL 12
#
# ---
#
# U={1,2,3,4,5,6} posibles opciones
#
# S={4,5,6} opciones exitosas
#
# R={5,5,2} respuesta de los dados lanzados
#
# Para que el ataque sea exitoso, al menos un valor de
# 𝑅
# R debe pertenecer a
# 𝑆
# S:
#
# 𝑅
# ∩
# 𝑆
# =
# {
# 5
# ,
# 2
# ,
# 2
# }
# ∩
# {
# 4
# ,
# 5
# ,
# 6
# }
# =
# {
# 5
# }
# R∩S={5,2,2}∩{4,5,6}={5}
# Dado que la intersección no es vacía (
# {
# 5
# }
# ≠
# ∅
# {5}
# 
# =∅), el ataque es exitoso.
#
# D={6}
#
# 6 x 2 = 12 al ser crtitico
#
# El ataque es exitoso porque
# 𝑅
# ∩
# 𝑆
# ≠
# ∅
# R∩S
# 
# =∅.
# El daño base es determinado por el conjunto
# 𝐷
# D.
# El daño es crítico porque
# 6
# ∈
# 𝐷
# 6∈D, lo que activa el multiplicador de 2x.
# Daño final = 12.

# %% [markdown]
# **QUINTA TIRADA**
# ---
# Ataque normal (requiere 4 o mas) bonus doble de daño
#
# Se tiran 3 dados: Dado 1: **6** (exitoso y critico). Dado 2: **4** (exitoso). Dado 3: **2** (fallido).
#
# Se tiran 2 dados para determinar el daño: Resultados: 2,1
#
# 2 x 2 (critico) = 4+1= 5 x 2 (doble de daño) = 10 DAñO TOTAL 10
#
# ---
#
# U={1,2,3,4,5,6} posibles opciones
#
# S={4,5,6} opciones exitosas
#
# R={6,4,2} respuesta de los dados lanzados
#
# R∩S={6,4,2}∩{4,5,6}={6,4}
# Dado que la intersección no es vacía (
# {
# 6
# ,
# 4
# }
# ≠
# ∅
# {6,4}
# 
# =∅), el ataque es exitoso.
#
# D={2,1} daño obtenido
#
# 2×2=4 se suma 1 = 5  5×2=10 doble de daño 10 TOTAL 10

# %% [markdown]
# **SEXTA TIRADA**
# ---
# Ataque rapido con congelacion (5 o mas)
#
# Se tiran 3 dados: Dado 1: **6** (exitoso y critico). Dado 2: **6** (exitoso y critico). Dado 3: **4** (exitoso).
#
# Se tiran 2 dados para determinar el daño: 6, 8
#
# 6 x 2 = 12 8 x 2=16(critico) 12 + 16 = 28 DAñO TOTAL 28
#
# ---
#
# U={1,2,3,4,5,6} posibles opciones
#
# S={4,5,6} opciones exitosas
#
# R={6,4,6} respuesta de los dados lanzados
#
# El ataque es exitoso si al menos un valor de
# 𝑅
# R pertenece a
# 𝑆
# S:
#
# 𝑅
# ∩
# 𝑆
# =
# {
# 6
# ,
# 6
# ,
# 4
# }
# ∩
# {
# 5
# ,
# 6
# }
# =
# {
# 6
# ,
# 6
# }
# R∩S={6,6,4}∩{5,6}={6,6}
#
#
# Como la intersección no es vacía (
# {
# 6
# ,
# 6
# }
# ≠
# ∅
# {6,6}
# 
# =∅), el ataque es exitoso.
#
# DAÑO:
#
# D={6,8}
#
# 6 × 2 = 12
#
# 8 × 2 = 16
#
# Resultado final: Daño total = 28.

# %% [markdown]
# **SEPTIMA TIRADA**
# ---
# Ataque normal (4 o mas) bonus de doble tiro
#
# * Se tiran 3 dados: Dado 1: **6** (exitoso y critico). Dado 2: **6** (exitoso y critico). Dado 3: **6** (exitoso y critico).
# * Se tiran 3 dados: Dado 1: **6** (exitoso y critico). Dado 2: **4** (exitoso). Dado 3: **4** (exitoso).
#
# 15+36= 51 DAñO
#
# ---
#
# U={1,2,3,4,5,6} posibles opciones
#
# S={4,5,6} opciones exitosas
#
# R={6,6,6} respuesta de los dados lanzados
#
# R={6,4,4} respuesta de los dados lanzados 2
#
# El ataque es exitoso si al menos un valor de
# 𝑅
# 1
# R
# 1
# ​
#   y
# 𝑅
# 2
# R
# 2
# ​
#
#
#   pertenece a
# 𝑆
# S:
#
# 𝑅
# 1
# ∩
# 𝑆
# =
# {
# 6
# ,
# 6
# ,
# 6
# }
# ∩
# {
# 4
# ,
# 5
# ,
# 6
# }
# =
# {
# 6
# ,
# 6
# ,
# 6
# }
# R
# 1
# ​
#
#  ∩S={6,6,6}∩{4,5,6}={6,6,6}
#
# 𝑅
# 2
# ∩
# 𝑆
# =
# {
# 6
# ,
# 4
# ,
# 4
# }
# ∩
# {
# 4
# ,
# 5
# ,
# 6
# }
# =
# {
# 6
# ,
# 4
# ,
# 4
# }
# R
# 2
# ​
#
#
#  ∩S={6,4,4}∩{4,5,6}={6,4,4}
#
#  Daño de la primera tirada: 15
# Daño de la segunda tirada: 36
# 15
# +
# 36
# =
# 51
#
# 15 + 36 = 51 DAÑO TOTAL

# %% [markdown]
# **OCTAVA TIRADA**
# ---
# Octava - ataque rapido sagrado (doble tirada) -  (5 o mas) - 3 dados, 6,4,1 (1 critico) - 3 dados 6,5,2  (1 critico de 2 exitosos) - no me acuerdo de los otros datos - pero el daño total es 44
#
# Ataque rapido sagrado (5 o mas) doble tiro
#
# * Se tiran 3 dados: Dado 1: **6** (exitoso y critico). Dado 2: **4** (fallido). Dado 3: **1** (fallido).
# * Se tiran 3 dados: Dado 1: **6** (exitoso y critico). Dado 2: **5** (exitoso). Dado 3: **2** (fallido).
